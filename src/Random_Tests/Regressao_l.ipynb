# %% [markdown]
# # Regressão Linear

# %%
import sys
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
sys.path.append(os.path.abspath('..'))  # Adds the parent directory

from Lib import compare
from Lib import compare_linked
from Lib import extract_from_data
from Lib import plot_param_vs_param

df = pd.read_csv('../../Data/EV_Data.csv')
df.head()
# Out:
#       region    category       parameter  mode powertrain  year      unit  \
# 0  Australia  Historical        EV sales  Cars        BEV  2011  Vehicles
# 1  Australia  Historical  EV stock share  Cars         EV  2011   percent
# 2  Australia  Historical  EV sales share  Cars         EV  2011   percent
# 3  Australia  Historical        EV stock  Cars        BEV  2011  Vehicles
# 4  Australia  Historical        EV stock  Cars        BEV  2012  Vehicles
#
#        value
# 0   49.00000
# 1    0.00039
# 2    0.00650
# 3   49.00000
# 4  220.00000

# %%
compare(df, 'Europe', 'EV sales', 'Electricity demand')
compare_linked(df, 'Europe', 'EV sales', 'Electricity demand')
plot_param_vs_param(df, 'Europe', 'EV sales', 'Electricity demand')
